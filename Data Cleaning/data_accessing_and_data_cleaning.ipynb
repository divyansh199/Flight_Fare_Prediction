# %% [markdown]
# ## Problem Statement
# Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travelers saying that flight ticket prices are so unpredictable. That’s why we will try to use machine learning to solve this problem. This can help airlines by predicting what prices they can maintain.

# %% [markdown]
# ## Introduction
# There is dataset given which consist the data of the airline and according to that data the price of the fare is given

# %% [markdown]
# ## 1. 📥 Data Accessing

# %% [markdown]
# 1. Since the data is given in excel format we have to use pandas read_excel fucntion to convert the excel file into dataframe
# 2. import pandas library

# %%
import pandas as pd
import numpy as np
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings("ignore")  # Ignore all warnings

# %%
flight = pd.read_excel("Flight_Fare.xlsx")

# %%
flight
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# #### Basic Data Information

# %% [markdown]
# There are __10683 rows__ and __11 columns__
#
# ##### Column Description
#
# __1. Airline :-__ Name of the Airline like Indigo, Air Inida ...etc.<br>
# __2. Date_of_Journey :-__ On This Date the passanger will start its journey given in format dd/mm/yyyy.<br>
# __3. Source :-__ Name of the place where the passenger’s journey will start.<br>
# __4. Destination :-__  Name of the place to where passengers wanted to travel.<br>
# __5. Route :-__ The route is through which passengers have opted to travel from his/her source to their destination.<br>
# __6. Dep_Time :-__ The Time at which flight will takeoff and passengers will start there journey.<br>
# __7. Arrival_Time :-__ Arrival time is when the passenger will reach his/her destination.<br>
# __8. Duration :-__ Duration is the whole period that a flight will take to complete its journey from source to destination.<br>
# __9. Total_Stops :-__ This will let us know in how many places flights will stop there for the flight in the whole journey.<br>
# __10. Additional_Info :-__ Information about food, kind of food, and other amenities.<br>
# __11. Price :-__ Price of the flight for a complete journey including all the expenses before onboarding.<br>

# %% [markdown]
# ## 2. 🧹 Data Cleaning

# %% [markdown]
# First will try perform data analysis to list down all the issues in dataset into two categories __Quality Issue__ and __Tidiness Issue__ <br>
# quality issue consist issues like Duplicate data, Missing data, Corrupt data, Inaccurate data.<br>
# tidness issue consist the structrual part of the data

# %% [markdown]
# #### Data Analysis

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# ❌ Here we can see that __Date_of_Journey__ has given data type object which is wrong its a __validity issue__

# %%
flight["Price"].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
flight[flight["Price"] == flight["Price"].max()]
# Out:
#                    Airline Date_of_Journey    Source Destination  \
# 2924  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                 Route Dep_Time Arrival_Time Duration Total_Stops  \
# 2924  BLR → BOM → DEL    05:45        11:25   5h 40m      1 stop
#
#      Additional_Info  Price
# 2924  Business class  79512

# %%
flight.duplicated().sum()
# Out:
# 220

# %%
flight[flight.duplicated()]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 683    Jet Airways       1/06/2019     Delhi      Cochin
# 1061     Air India      21/05/2019     Delhi      Cochin
# 1348     Air India      18/05/2019     Delhi      Cochin
# 1418   Jet Airways       6/06/2019     Delhi      Cochin
# 1674        IndiGo      24/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683    DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061   DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# 1348   DEL → HYD → BOM → COK    17:15  19:15 19 May      26h     2 stops
# 1418   DEL → JAI → BOM → COK    05:30  04:25 07 Jun  22h 55m     2 stops
# 1674               BLR → DEL    18:25         21:20   2h 55m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10594  DEL → AMD → BOM → COK    23:05  12:35 28 Jun  13h 30m     2 stops
# 10616  DEL → JAI → BOM → COK    09:40  12:35 02 Jun  26h 55m     2 stops
# 10634  DEL → JAI → BOM → COK    09:40  12:35 07 Jun  26h 55m     2 stops
# 10672  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
#
#                    Additional_Info  Price
# 683                        No info  13376
# 1061                       No info  10231
# 1348                       No info  12392
# 1418   In-flight meal not included  10368
# 1674                       No info   7303
# ...                            ...    ...
# 10594                      No info  12819
# 10616                      No info  13014
# 10634  In-flight meal not included  11733
# 10672  In-flight meal not included  11150
# 10673                      No info  16704
#
# [220 rows x 11 columns]

# %% [markdown]
# ❌ Here we can see that there are __220 rows__ are duplicated which is a __validity issue__

# %%
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flight[flight.isnull().any(axis=1)]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %% [markdown]
# ❌ Here we can see that row number 9039 has missing value in __Route__ and __Total_Stops__ `completness`

# %%
l = [i for i in flight.columns if flight[i].dtype == 'O']
def unique_columns(list: l)->str:
    for i in l:
        print(f'{pd.Series(flight[i].dropna().unique())}')
        print("")
        print(f'{flight[i].value_counts()}')
        print("")
        print("="*50)

# %%
unique_columns(l)
# Out:
# 0                                IndiGo
# 1                             Air India
# 2                           Jet Airways
# 3                              SpiceJet
# 4                     Multiple carriers
# 5                                 GoAir
# 6                               Vistara
# 7                              Air Asia
# 8               Vistara Premium economy
# 9                  Jet Airways Business
# 10    Multiple carriers Premium economy
# 11                               Trujet
# dtype: object
#
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64
#
# ==================================================
# 0     24/03/2019
# 1      1/05/2019
# 2      9/06/2019
# 3     12/05/2019
# 4     01/03/2019
# 5     24/06/2019
# 6     12/03/2019
# 7     27/05/2019
# 8      1/06/2019
# 9     18/04/2019
# 10     9/05/2019
# 11    24/04/2019
# 12     3/03/2019
# 13    15/04/2019
# 14    12/06/2019
# 15     6/03/2019
# 16    21/03/2019
# 17     3/04/2019
# 18     6/05/2019
# 19    15/05/2019
# 20    18/06/2019
# 21    15/06/2019
# 22     6/04/2019
# 23    18/05/2019
# 24    27/06/2019
# 25    21/05/2019
# 26    06/03/2019
# 27     3/06/2019
# 28    15/03/2019
# 29     3/05/2019
# 30     9/03/2019
# 31     6/06/2019
# 32    24/05/2019
# 33    09/03/2019
# 34     1/04/2019
# 35    21/04/2019
# 36    21/06/2019
# 37    27/03/2019
# 38    18/03/2019
# 39    12/04/2019
# 40     9/04/2019
# 41     1/03/2019
# 42    03/03/2019
# 43    27/04/2019
# dtype: object
#
# Date_of_Journey
# 18/05/2019    504
# 6/06/2019     503
# 21/05/2019    497
# 9/06/2019     495
# 12/06/2019    493
# 9/05/2019     484
# 21/03/2019    423
# 15/05/2019    405
# 27/05/2019    382
# 27/06/2019    355
# 24/06/2019    351
# 1/06/2019     342
# 3/06/2019     333
# 15/06/2019    328
# 24/03/2019    323
# 6/03/2019     308
# 27/03/2019    299
# 24/05/2019    286
# 6/05/2019     282
# 1/05/2019     277
# 12/05/2019    259
# 1/04/2019     257
# 3/03/2019     218
# 9/03/2019     200
# 15/03/2019    162
# 18/03/2019    156
# 01/03/2019    152
# 12/03/2019    142
# 9/04/2019     125
# 3/04/2019     110
# 21/06/2019    109
# 18/06/2019    105
# 09/03/2019    102
# 6/04/2019     100
# 03/03/2019     97
# 06/03/2019     95
# 27/04/2019     94
# 24/04/2019     92
# 3/05/2019      90
# 15/04/2019     89
# 21/04/2019     82
# 18/04/2019     67
# 12/04/2019     63
# 1/03/2019      47
# Name: count, dtype: int64
#
# ==================================================
# 0    Banglore
# 1     Kolkata
# 2       Delhi
# 3     Chennai
# 4      Mumbai
# dtype: object
#
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64
#
# ==================================================
# 0    New Delhi
# 1     Banglore
# 2       Cochin
# 3      Kolkata
# 4        Delhi
# 5    Hyderabad
# dtype: object
#
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64
#
# ==================================================
# 0                              BLR → DEL
# 1                  CCU → IXR → BBI → BLR
# 2                  DEL → LKO → BOM → COK
# 3                        CCU → NAG → BLR
# 4                        BLR → NAG → DEL
#                      ...
# 123                BOM → VNS → DEL → HYD
# 124          BLR → HBX → BOM → NAG → DEL
# 125                BLR → BOM → IXC → DEL
# 126    BLR → CCU → BBI → HYD → VGA → DEL
# 127                      BOM → BBI → HYD
# Length: 128, dtype: object
#
# Route
# DEL → BOM → COK          2376
# BLR → DEL                1552
# CCU → BOM → BLR           979
# CCU → BLR                 724
# BOM → HYD                 621
#                          ...
# CCU → VTZ → BLR             1
# CCU → IXZ → MAA → BLR       1
# BOM → COK → MAA → HYD       1
# BOM → CCU → HYD             1
# BOM → BBI → HYD             1
# Name: count, Length: 128, dtype: int64
#
# ==================================================
# 0      22:20
# 1      05:50
# 2      09:25
# 3      18:05
# 4      16:50
#        ...
# 217    10:25
# 218    12:05
# 219    11:20
# 220    21:40
# 221    03:00
# Length: 222, dtype: object
#
# Dep_Time
# 18:55    233
# 17:00    227
# 07:05    205
# 10:00    203
# 07:10    202
#         ...
# 16:25      1
# 01:35      1
# 21:35      1
# 04:15      1
# 03:00      1
# Name: count, Length: 222, dtype: int64
#
# ==================================================
# 0       01:10 22 Mar
# 1              13:15
# 2       04:25 10 Jun
# 3              23:30
# 4              21:35
#             ...
# 1338    00:50 28 Jun
# 1339    22:40 07 Jun
# 1340    06:50 10 Mar
# 1341    00:05 19 Mar
# 1342    21:20 13 Mar
# Length: 1343, dtype: object
#
# Arrival_Time
# 19:00           423
# 21:00           360
# 19:15           333
# 16:10           154
# 12:35           122
#                ...
# 00:25 02 Jun      1
# 08:55 13 Mar      1
# 11:05 19 May      1
# 12:30 22 May      1
# 21:20 13 Mar      1
# Name: count, Length: 1343, dtype: int64
#
# ==================================================
# 0       2h 50m
# 1       7h 25m
# 2          19h
# 3       5h 25m
# 4       4h 45m
#         ...
# 363    32h 20m
# 364    20h 50m
# 365    40h 20m
# 366    13h 35m
# 367    47h 40m
# Length: 368, dtype: object
#
# Duration
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 31h 30m      1
# 30h 25m      1
# 42h 5m       1
# 4h 10m       1
# 47h 40m      1
# Name: count, Length: 368, dtype: int64
#
# ==================================================
# 0    non-stop
# 1     2 stops
# 2      1 stop
# 3     3 stops
# 4     4 stops
# dtype: object
#
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64
#
# ==================================================
# 0                         No info
# 1     In-flight meal not included
# 2    No check-in baggage included
# 3                 1 Short layover
# 4                         No Info
# 5                  1 Long layover
# 6                 Change airports
# 7                  Business class
# 8                  Red-eye flight
# 9                  2 Long layover
# dtype: object
#
# Additional_Info
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64
#
# ==================================================

# %% [markdown]
# #### ❌ Issues
# 1.Here we can see that there is __tideness issue__ in __Date_of_Journey__<br>
# 2.There is __tideness issue__ in __Dep_Time__ and __Arrival_Time__ also in __Arrival_Time__ there sometimes day and month is also give which is a __completness issue__<br>
# 3. In __Duration__ there is __tideness and validity issue__ `h and m` present<br>
# 4. In __Additional_Info__ there is __consistancy issue__ `No info -> No Info`<br>

# %% [markdown]
# ### 📋 Listing The Issues
# #### ⚠️ Quality Issues
# 1. __Date_of_Journey__ -> Wrong data type given (object) `validity issue`<br>
# 2. __220 rows__ are duplicated  `validity issue`<br>
# 3. __Route__,__Total_Stops__ -> null value in row number __9030__ `completeness issue`<br>
# 4. __Arrival_Time__ ->  Sometimes day and month given and sometime not `completeness issue`<br>
# 6. __Duration__ -> letter h & m present in between hour and minutes `validity issue`<br>
# 7. __Additional_Info__ -> No info and No Info are same but written differently `consistancy issue`<br>
#
# #### ⚠️ Tideness Issues
# 1. __Date_of_Journey__  -> day,month and year must be in seperate columns<br>
# 2. __Dep_Time__ and __Arrival_Time__ -> hour and minutes must be in seperate columns<br>
# 3. __Duration__ -> hour and minutes must be in seperate columns<br>

# %% [markdown]
# ### ✅ Rectifing Issues

# %% [markdown]
# First create a copy of Original Data Frame

# %%
df_flight = flight.copy()

# %% [markdown]
# First we will solve validity issues
# 1. __Date_of_Journey__ has given data type as Object , we have to change the data type from object to __datetime__ => by using __pd.to_datetime__ we can change the data type

# %%
df_flight["Date_of_Journey"] = pd.to_datetime(df_flight["Date_of_Journey"])

# %%
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  datetime64[ns]
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 918.2+ KB

# %% [markdown]
# 2. There are __220 rows__ are duplicate We will remove all duplicate rows ==> by using __drop_duplicates(keep = 'first', axis = 0)__

# %%
df_flight.drop_duplicates(keep = 'first',ignore_index = True,inplace = True)

# %%
df_flight.shape[0]
# Out:
# 10463

# %% [markdown]
# <span style="color: green;">3. We can see that there is only one row which contains null values so we can remove that row ===> by using __dropna__</span>

# %%
df_flight.dropna(inplace = True)

# %%
df_flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df_flight.shape[0]
# Out:
# 10462

# %% [markdown]
# <span style="color: Green;"> 4. we will remove the day and month part from __Arrival_Time__ </span>

# %%
df_flight['Arrival_Time'] = df_flight['Arrival_Time'].str.strip().apply(lambda x : x.split()[0])

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20        01:10   2h 50m    non-stop         No info   3897
# 1    05:50        13:15   7h 25m     2 stops         No info   7662
# 2    09:25        04:25      19h     2 stops         No info  13882
# 3    18:05        23:30   5h 25m      1 stop         No info   6218
# 4    16:50        21:35   4h 45m      1 stop         No info  13302

# %%
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# 5. Now we will remove __h and m__ from __duration__

# %%
def rep1(x):
    if ('h' in x) and ('m' in x):
        return x.replace('h','').replace('m','').replace(' ',':')
    elif 'm' not in x:
        j = x.replace('h','')
        return j+":0"
    else:
        j = x.replace('m','')
        return '0:'+ j
        
df_flight['Duration'] = df_flight['Duration'].str.strip().apply(lambda x : rep1(x))

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20        01:10     2:50    non-stop         No info   3897
# 1    05:50        13:15     7:25     2 stops         No info   7662
# 2    09:25        04:25     19:0     2 stops         No info  13882
# 3    18:05        23:30     5:25      1 stop         No info   6218
# 4    16:50        21:35     4:45      1 stop         No info  13302

# %% [markdown]
# 6. we have to replace __No info__ with __No Info__ in __Additional_Info__ ==> using __replace()__

# %%
df_flight['Additional_Info'] = df_flight['Additional_Info'].str.replace('No info', 'No Info')

# %%
list(df_flight['Additional_Info'].unique())
# Out:
# ['No Info',
#  'In-flight meal not included',
#  'No check-in baggage included',
#  '1 Short layover',
#  '1 Long layover',
#  'Change airports',
#  'Business class',
#  'Red-eye flight',
#  '2 Long layover']

# %%
df_flight.sample(50)
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 2414            SpiceJet      2019-03-18    Mumbai   Hyderabad
# 2707            SpiceJet      2019-05-21    Mumbai   Hyderabad
# 3842              IndiGo      2019-05-03   Kolkata    Banglore
# 1652           Air India      2019-03-21  Banglore   New Delhi
# 1048             Vistara      2019-05-24   Kolkata    Banglore
# 8372   Multiple carriers      2019-05-15     Delhi      Cochin
# 9443         Jet Airways      2019-05-01   Kolkata    Banglore
# 6595              IndiGo      2019-03-09  Banglore   New Delhi
# 8850              IndiGo      2019-06-03   Kolkata    Banglore
# 7429   Multiple carriers      2019-05-18     Delhi      Cochin
# 1981            SpiceJet      2019-06-06    Mumbai   Hyderabad
# 1511         Jet Airways      2019-05-18    Mumbai   Hyderabad
# 6748           Air India      2019-03-09     Delhi      Cochin
# 9403         Jet Airways      2019-06-09   Kolkata    Banglore
# 7010           Air India      2019-05-18   Kolkata    Banglore
# 7568            SpiceJet      2019-04-12  Banglore       Delhi
# 2693              IndiGo      2019-05-15   Kolkata    Banglore
# 5913             Vistara      2019-04-01   Kolkata    Banglore
# 7712            SpiceJet      2019-03-15   Chennai     Kolkata
# 9684         Jet Airways      2019-05-21   Kolkata    Banglore
# 323          Jet Airways      2019-03-12  Banglore   New Delhi
# 5709         Jet Airways      2019-05-18  Banglore       Delhi
# 5816            Air Asia      2019-06-27   Kolkata    Banglore
# 1904         Jet Airways      2019-06-09   Kolkata    Banglore
# 3175         Jet Airways      2019-06-09     Delhi      Cochin
# 5788           Air India      2019-05-21   Kolkata    Banglore
# 14                IndiGo      2019-04-24   Kolkata    Banglore
# 3520            SpiceJet      2019-06-06    Mumbai   Hyderabad
# 2198           Air India      2019-04-06  Banglore       Delhi
# 1360           Air India      2019-03-06   Kolkata    Banglore
# 7924            SpiceJet      2019-03-01    Mumbai   Hyderabad
# 10189          Air India      2019-03-09  Banglore   New Delhi
# 589          Jet Airways      2019-03-15  Banglore   New Delhi
# 9323              IndiGo      2019-04-03     Delhi      Cochin
# 5479         Jet Airways      2019-05-27     Delhi      Cochin
# 2900           Air India      2019-03-09     Delhi      Cochin
# 8439         Jet Airways      2019-06-06     Delhi      Cochin
# 8703              IndiGo      2019-05-09     Delhi      Cochin
# 6811   Multiple carriers      2019-03-06     Delhi      Cochin
# 59               Vistara      2019-03-06    Mumbai   Hyderabad
# 3296              IndiGo      2019-05-21     Delhi      Cochin
# 9965            Air Asia      2019-05-06   Kolkata    Banglore
# 639            Air India      2019-06-15   Chennai     Kolkata
# 5241         Jet Airways      2019-06-09   Kolkata    Banglore
# 3628           Air India      2019-06-01     Delhi      Cochin
# 4895         Jet Airways      2019-03-24  Banglore   New Delhi
# 2596         Jet Airways      2019-06-12  Banglore       Delhi
# 6716            SpiceJet      2019-05-12   Kolkata    Banglore
# 711          Jet Airways      2019-03-27     Delhi      Cochin
# 10309          Air India      2019-05-24   Kolkata    Banglore
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 2414               BOM → HYD    22:45        00:10     1:25    non-stop
# 2707               BOM → HYD    22:45        00:15     1:30    non-stop
# 3842               CCU → BLR    22:15        00:50     2:35    non-stop
# 1652         BLR → BOM → DEL    08:50        23:15    14:25      1 stop
# 1048         CCU → DEL → BLR    07:10        18:50    11:40      1 stop
# 8372         DEL → BOM → COK    07:30        19:00    11:30      1 stop
# 9443         CCU → BOM → BLR    14:05        09:20    19:15      1 stop
# 6595               BLR → DEL    07:10        10:05     2:55    non-stop
# 8850               CCU → BLR    11:30        14:05     2:35    non-stop
# 7429         DEL → BOM → COK    09:15        19:15     10:0      1 stop
# 1981               BOM → HYD    22:45        00:15     1:30    non-stop
# 1511               BOM → HYD    19:35        21:05     1:30    non-stop
# 6748   DEL → CCU → BOM → COK    20:15        19:15     23:0     2 stops
# 9403         CCU → DEL → BLR    20:25        23:35    27:10      1 stop
# 7010   CCU → BOM → HBX → BLR    09:25        17:20    31:55     2 stops
# 7568               BLR → DEL    09:30        12:20     2:50    non-stop
# 2693               CCU → BLR    14:25        16:55     2:30    non-stop
# 5913         CCU → DEL → BLR    20:20        23:25     27:5      1 stop
# 7712               MAA → CCU    08:20        10:35     2:15    non-stop
# 9684         CCU → DEL → BLR    20:25        18:00    21:35      1 stop
# 323          BLR → MAA → DEL    09:45        00:30    14:45      1 stop
# 5709               BLR → DEL    07:10        10:10      3:0    non-stop
# 5816               CCU → BLR    22:50        01:20     2:30    non-stop
# 1904         CCU → BOM → BLR    21:10        10:05    12:55      1 stop
# 3175         DEL → BOM → COK    20:55        19:00     22:5      1 stop
# 5788   CCU → BOM → COK → BLR    09:25        13:45    28:20     2 stops
# 14                 CCU → BLR    17:15        19:50     2:35    non-stop
# 3520               BOM → HYD    22:45        00:15     1:30    non-stop
# 2198               BLR → DEL    10:00        12:45     2:45    non-stop
# 1360               CCU → BLR    20:45        23:20     2:35    non-stop
# 7924               BOM → HYD    05:45        07:05     1:20    non-stop
# 10189              BLR → DEL    21:10        23:55     2:45    non-stop
# 589          BLR → BOM → DEL    05:45        10:45      5:0      1 stop
# 9323         DEL → HYD → COK    07:35        12:10     4:35      1 stop
# 5479         DEL → BOM → COK    10:00        12:35    26:35      1 stop
# 2900         DEL → BOM → COK    08:40        19:15    10:35      1 stop
# 8439         DEL → BOM → COK    15:00        04:25    13:25      1 stop
# 8703         DEL → BOM → COK    09:15        01:30    16:15      1 stop
# 6811         DEL → BOM → COK    04:00        18:50    14:50      1 stop
# 59           BOM → DEL → HYD    15:40        16:45     25:5      1 stop
# 3296         DEL → BOM → COK    17:10        01:30     8:20      1 stop
# 9965         CCU → DEL → BLR    07:35        19:25    11:50      1 stop
# 639                MAA → CCU    11:40        13:55     2:15    non-stop
# 5241         CCU → BOM → BLR    08:25        20:45    12:20      1 stop
# 3628         DEL → MAA → COK    12:30        09:25    20:55      1 stop
# 4895         BLR → BOM → DEL    22:50        12:15    13:25      1 stop
# 2596               BLR → DEL    17:45        20:45      3:0    non-stop
# 6716         CCU → MAA → BLR    15:05        20:20     5:15      1 stop
# 711    DEL → AMD → BOM → COK    19:10        19:45    24:35     2 stops
# 10309  CCU → BBI → BOM → BLR    12:00        07:55    19:55     2 stops
#
#                     Additional_Info  Price
# 2414   No check-in baggage included   1965
# 2707   No check-in baggage included   1965
# 3842                        No Info   4804
# 1652                        No Info   6824
# 1048                        No Info   9555
# 8372                        No Info   9315
# 9443    In-flight meal not included   9663
# 6595                        No Info   7303
# 8850                        No Info   4804
# 7429                        No Info   8309
# 1981   No check-in baggage included   1965
# 1511    In-flight meal not included   3210
# 6748                        No Info  19681
# 9403                        No Info  12692
# 7010                        No Info  13616
# 7568   No check-in baggage included   4885
# 2693                        No Info   5224
# 5913                        No Info   7927
# 7712                        No Info   6300
# 9684                        No Info  14151
# 323                         No Info  11507
# 5709    In-flight meal not included   5198
# 5816                        No Info   3807
# 1904                        No Info  14939
# 3175                        No Info  14924
# 5788                        No Info  11542
# 14                          No Info   4804
# 3520                        No Info   2017
# 2198                        No Info   5176
# 1360                        No Info   4435
# 7924                        No Info  12475
# 10189                       No Info   7591
# 589     In-flight meal not included   9134
# 9323                        No Info   5073
# 5479    In-flight meal not included  12898
# 2900                        No Info  18959
# 8439    In-flight meal not included  10262
# 8703                        No Info   8854
# 6811                        No Info  13399
# 59                          No Info  12395
# 3296                        No Info   6794
# 9965                        No Info   5192
# 639                         No Info   4667
# 5241    In-flight meal not included  10844
# 3628                        No Info   7480
# 4895    In-flight meal not included   7832
# 2596    In-flight meal not included   5769
# 6716                        No Info   4649
# 711                         No Info  10976
# 10309                       No Info   9416

# %% [markdown]
# Now we will solve the structrual part which is a tideness issues

# %% [markdown]
# 1. spliting the __Date_of_Journey__ into __Journey_Day__ and __Journey_Month__

# %%
df_flight["Journey_Day"] = df_flight["Date_of_Journey"].dt.day
df_flight["Journey_Month"] = df_flight["Date_of_Journey"].dt.month

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20        01:10     2:50    non-stop         No Info   3897
# 1    05:50        13:15     7:25     2 stops         No Info   7662
# 2    09:25        04:25     19:0     2 stops         No Info  13882
# 3    18:05        23:30     5:25      1 stop         No Info   6218
# 4    16:50        21:35     4:45      1 stop         No Info  13302
#
#    Journey_Day  Journey_Month
# 0           24              3
# 1            1              5
# 2            9              6
# 3           12              5
# 4            1              3

# %% [markdown]
# 2. spliting the __Dep_Time__ and __Arrival_Time__ into __Dep_Hours__,__Dep_Mins__,__Arrival__Hours__,__Arrival_Mins__---- but first we have to change the data type of all from object to __datetime.time__

# %%
df_flight['Dep_Hours'] = pd.to_datetime(df_flight["Dep_Time"]).dt.hour
df_flight['Dep_Mins'] = pd.to_datetime(df_flight["Dep_Time"]).dt.minute
df_flight['Arrival_Hours'] = pd.to_datetime(df_flight["Arrival_Time"]).dt.hour
df_flight['Arrival_Mins'] = pd.to_datetime(df_flight["Arrival_Time"]).dt.minute

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20        01:10     2:50    non-stop         No Info   3897
# 1    05:50        13:15     7:25     2 stops         No Info   7662
# 2    09:25        04:25     19:0     2 stops         No Info  13882
# 3    18:05        23:30     5:25      1 stop         No Info   6218
# 4    16:50        21:35     4:45      1 stop         No Info  13302
#
#    Journey_Day  Journey_Month  Dep_Hours  Dep_Mins  Arrival_Hours  \
# 0           24              3         22        20              1
# 1            1              5          5        50             13
# 2            9              6          9        25              4
# 3           12              5         18         5             23
# 4            1              3         16        50             21
#
#    Arrival_Mins
# 0            10
# 1            15
# 2            25
# 3            30
# 4            35

# %% [markdown]
# 3. Spliting the __Duration__ into __Duration_Hours__, __Duration_Mins__

# %%
df_flight['Duration_Hours'] = df_flight['Duration'].str.split(':').apply(lambda x : x[0])
df_flight['Duration_Mins'] = df_flight['Duration'].str.split(':').apply(lambda x : x[1])

# %%
df_flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20        01:10     2:50    non-stop         No Info   3897
# 1    05:50        13:15     7:25     2 stops         No Info   7662
# 2    09:25        04:25     19:0     2 stops         No Info  13882
# 3    18:05        23:30     5:25      1 stop         No Info   6218
# 4    16:50        21:35     4:45      1 stop         No Info  13302
#
#    Journey_Day  Journey_Month  Dep_Hours  Dep_Mins  Arrival_Hours  \
# 0           24              3         22        20              1
# 1            1              5          5        50             13
# 2            9              6          9        25              4
# 3           12              5         18         5             23
# 4            1              3         16        50             21
#
#    Arrival_Mins Duration_Hours Duration_Mins
# 0            10              2            50
# 1            15              7            25
# 2            25             19             0
# 3            30              5            25
# 4            35              4            45

# %% [markdown]
# At last we will delete columns __Date_of_Journey__, __Dep_Time__, __Arrival_Time__ and __Duration__ because we already splited them into different columns

# %%
df_flight.drop(columns = ['Date_of_Journey','Dep_Time','Arrival_Time','Duration'],axis = 1, inplace = True)

# %%
df_flight.sample(20)
# Out:
#                  Airline    Source Destination                  Route  \
# 6439         Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 4531           Air India     Delhi      Cochin        DEL → MAA → COK
# 1506         Jet Airways  Banglore   New Delhi        BLR → MAA → DEL
# 4236         Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 10368        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 8647         Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 6152            Air Asia  Banglore       Delhi              BLR → DEL
# 6206           Air India   Kolkata    Banglore  CCU → BBI → HYD → BLR
# 9434              IndiGo     Delhi      Cochin        DEL → BOM → COK
# 6402               GoAir  Banglore       Delhi              BLR → DEL
# 1984         Jet Airways  Banglore       Delhi              BLR → DEL
# 7258             Vistara  Banglore       Delhi              BLR → DEL
# 8875         Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 2362           Air India  Banglore   New Delhi  BLR → HYD → VGA → DEL
# 861    Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 5474              IndiGo   Kolkata    Banglore        CCU → IXA → BLR
# 1669         Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 6832              IndiGo   Chennai     Kolkata              MAA → CCU
# 5699              IndiGo     Delhi      Cochin        DEL → BOM → COK
# 3237         Jet Airways     Delhi      Cochin        DEL → BOM → COK
#
#       Total_Stops              Additional_Info  Price  Journey_Day  \
# 6439       1 stop                      No Info  14571            9
# 4531       1 stop                      No Info   6482           21
# 1506       1 stop  In-flight meal not included  10562            9
# 4236       1 stop  In-flight meal not included   9663            1
# 10368      1 stop  In-flight meal not included   9663            6
# 8647       1 stop  In-flight meal not included  10844           15
# 6152     non-stop                      No Info   4282           24
# 6206      2 stops                      No Info   6117           15
# 9434       1 stop                      No Info   6069            6
# 6402     non-stop                      No Info   3898            9
# 1984     non-stop                      No Info   8016            1
# 7258     non-stop                      No Info   4668            9
# 8875       1 stop               1 Long layover  31825            1
# 2362      2 stops                      No Info  12734           12
# 861        1 stop                      No Info   7155           27
# 5474       1 stop                      No Info   9413           24
# 1669       1 stop  In-flight meal not included   9899           12
# 6832     non-stop                      No Info   3597           15
# 5699       1 stop                      No Info   6093            6
# 3237       1 stop  In-flight meal not included  10262            1
#
#        Journey_Month  Dep_Hours  Dep_Mins  Arrival_Hours  Arrival_Mins  \
# 6439               6          6        30             18            15
# 4531               3         17        20              9            25
# 1506               3          9        45              0            30
# 4236               5          8        25              9            20
# 10368              5         14         5             20            45
# 8647               5         16        30             18            15
# 6152               6          4        55              7            45
# 6206               5          9        10              4            40
# 9434               6         16         0             21             0
# 6402               6          7        45             10            40
# 1984               6         19        50             22            50
# 7258               6         11        30             14            20
# 8875               3         22        50             11            25
# 2362               3          6        50             11            20
# 861                6          4        55             19            15
# 5474               3         14        30             20            10
# 1669               6          6        30             16            20
# 6832               6         13        15             15            35
# 5699               6          7        30             21             0
# 3237               6         20        55             12            35
#
#       Duration_Hours Duration_Mins
# 6439              11            45
# 4531              16             5
# 1506              14            45
# 4236              24            55
# 10368              6            40
# 8647              25            45
# 6152               2            50
# 6206              19            30
# 9434               5             0
# 6402               2            55
# 1984               3             0
# 7258               2            50
# 8875              12            35
# 2362              28            30
# 861               14            20
# 5474               5            40
# 1669               9            50
# 6832               2            20
# 5699              13            30
# 3237              15            40

# %%
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10462 entries, 0 to 10462
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10462 non-null  object
#  1   Source           10462 non-null  object
#  2   Destination      10462 non-null  object
#  3   Route            10462 non-null  object
#  4   Total_Stops      10462 non-null  object
#  5   Additional_Info  10462 non-null  object
#  6   Price            10462 non-null  int64
#  7   Journey_Day      10462 non-null  int32
#  8   Journey_Month    10462 non-null  int32
#  9   Dep_Hours        10462 non-null  int32
#  10  Dep_Mins         10462 non-null  int32
#  11  Arrival_Hours    10462 non-null  int32
#  12  Arrival_Mins     10462 non-null  int32
#  13  Duration_Hours   10462 non-null  object
#  14  Duration_Mins    10462 non-null  object
# dtypes: int32(6), int64(1), object(8)
# memory usage: 1.0+ MB

# %% [markdown]
# ❌ here we can see that  __Duration_Hours__ and __Duration_Mins__ has data type object , we have to convert it into integer

# %%
df_flight[['Duration_Hours','Duration_Mins']]= df_flight[['Duration_Hours','Duration_Mins']].astype('int32')

# %%
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10462 entries, 0 to 10462
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10462 non-null  object
#  1   Source           10462 non-null  object
#  2   Destination      10462 non-null  object
#  3   Route            10462 non-null  object
#  4   Total_Stops      10462 non-null  object
#  5   Additional_Info  10462 non-null  object
#  6   Price            10462 non-null  int64
#  7   Journey_Day      10462 non-null  int32
#  8   Journey_Month    10462 non-null  int32
#  9   Dep_Hours        10462 non-null  int32
#  10  Dep_Mins         10462 non-null  int32
#  11  Arrival_Hours    10462 non-null  int32
#  12  Arrival_Mins     10462 non-null  int32
#  13  Duration_Hours   10462 non-null  int32
#  14  Duration_Mins    10462 non-null  int32
# dtypes: int32(8), int64(1), object(6)
# memory usage: 980.8+ KB

# %% [markdown]
# ### Now the Dataset is Clean but in EDA and Model creation there may be some posibilities that we have to clean dataset again

# %% [markdown]
# ## 3. 🗄️ We we save this dataset in an Excel File then Pass this File For EDA + Feature Engineering

# %%
df_flight.to_excel('clean_dataset_flight.xlsx',index = False)
